# %% [markdown]
# ## OVERVIEW OF OSEMiN

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jirvingphd/fsds_100719_cohort_notes/master/images/OSEMN.png' width=800>
#
# <center><a href="https://www.kdnuggets.com/2018/02/data-science-command-line-book-exploring-data.html">
#     </a></center>
#
#
# > <font size=2em>The Data Science Process we'll be using during this section--OSEMiN (pronounced "OH-sum", rhymes with "possum").  This is the most straightforward of the Data Science Processes discussed so far.  **Note that during this process, just like the others, the stages often blur together.***  It is completely acceptable (and ***often a best practice!) to float back and forth** between stages as you learn new things about your problem, dataset, requirements, etc.
# It's quite common to get to the modeling step and realize that you need to scrub your data a bit more or engineer a different feature and jump back to the "Scrub" stage, or go all the way back to the "Obtain" stage when you realize your current data isn't sufficient to solve this problem.
# As with any of these frameworks, *OSEMiN is meant to be treated as guidelines, not law.
# </font>
#
#
# ### OSEMN DETAILS
#
# **OBTAIN**
#
# - This step involves understanding stakeholder requirements, gathering information on the problem, and finally sourcing data that we think will be necessary for solving this problem.
#
# **SCRUB**
#
# - During this stage, we'll focus on preprocessing our data.  Important steps such as identifying and removing null values, dealing with outliers, normalizing data, and feature engineering/feature selection are handled around this stage.  The line with this stage really blurs with the _Explore_ stage, as it is common to only realize that certain columns require cleaning or preprocessing as a result of the visualzations and explorations done during Step 3.
#
# - Note that although technically, categorical data should be one-hot encoded during this step, in practice, it's usually done after data exploration.  This is because it is much less time-consuming to visualize and explore a few columns containing categorical data than it is to explore many different dummy columns that have been one-hot encoded.
#
# **EXPLORE**
#
# - This step focuses on getting to know the dataset you're working with. As mentioned above, this step tends to blend with the _Scrub_ step mentioned above.  During this step, you'll create visualizations to really get a feel for your dataset.  You'll focus on things such as understanding the distribution of different columns, checking for multicollinearity, and other tasks liek that.  If your project is a classification task, you may check the balance of the different classes in your dataset.  If your problem is a regression task, you may check that the dataset meets the assumptions necessary for a regression task.
#
# - At the end of this step, you should have a dataset ready for modeling that you've thoroughly explored and are extremely familiar with.
#
# **MODEL**
#
# - This step, as with the last two frameworks, is also pretty self-explanatory. It consists of building and tuning models using all the tools you have in your data science toolbox.  In practice, this often means defining a threshold for success, selecting machine learning algorithms to test on the project, and tuning the ones that show promise to try and increase your results.  As with the other stages, it is both common and accepted to realize something, jump back to a previous stage like _Scrub_ or _Explore_, and make some changes to see how it affects the model.
#
# **iNTERPRET**
#
# - During this step, you'll interpret the results of your model(s), and communicate results to stakeholders.  As with the other frameworks, communication is incredibily important! During this stage, you may come to realize that further investigation is needed, or more data.  That's totally fine--figure out what's needed, go get it, and start the process over! If your results are satisfactory to all stakeholders involved, you may also go from this stage right into productionizing your model and automating processes necessary to support it.

# %% [markdown]
# ## PROCESS CHECKLIST

# %% [markdown]
# > Keep in mind that it is normal to jump between the OSEMN phases and some of them will blend together, like SCRUB and EXPLORE.

# %% [markdown]
# 1. **[OBTAIN](#OBTAIN)**
#     - Import data, inspect, check for datatypes to convert and null values
#     - Display header and info.
#     - Drop any unneeded columns, if known (`df.drop(['col1','col2'],axis=1,inplace=True`)
#     <br><br>
#
#
# 2. **[SCRUB](#SCRUB)**
#     - Recast data types, identify outliers, check for multicollinearity, normalize data**
#     - Check and cast data types
#         - [ ] Check for #'s that are store as objects (`df.info()`,`df.describe()`)
#             - when converting to #'s, look for odd values (like many 0's), or strings that can't be converted.
#             - Decide how to deal weird/null values (`df.unique()`, `df.isna().sum()`)
#             - `df.fillna(subset=['col_with_nulls'],'fill_value')`, `df.replace()`
#         - [ ] Check for categorical variables stored as integers.
#             - May be easier to tell when you make a scatter plotm or `pd.plotting.scatter_matrix()`
#
#     - [ ] Check for missing values  (df.isna().sum())
#         - Can drop rows or colums
#         - For missing numeric data with median or bin/convert to categorical
#         - For missing categorical data: make NaN own category OR replace with most common category
#     - [ ] Check for multicollinearity
#         - Use seaborn to make correlation matrix plot
#         - Good rule of thumb is anything over 0.75 corr is high, remove the variable that has the most correl with the largest # of variables
#     - [ ] Normalize data (may want to do after some exploring)
#         - Most popular is Z-scoring (but won't fix skew)
#         - Can log-transform to fix skewed data
#
#
# 3. **[EXPLORE](#EXPLORE)**
#     - [ ] Check distributions, outliers, etc**
#     - [ ] Check scales, ranges (df.describe())
#     - [ ] Check histograms to get an idea of distributions (df.hist()) and data transformations to perform.
#         - Can also do kernel density estimates
#     - [ ] Use scatter plots to check for linearity and possible categorical variables (`df.plot("x","y")`)
#         - categoricals will look like vertical lines
#     - [ ] Use `pd.plotting.scatter_matrix(df)` to visualize possible relationships
#     - [ ] Check for linearity.
#
#
# 4. **[MODEL](#MODEL)**
#
#     - **Fit an initial model:**
#         - Run an initial model and get results
#
#     - **Holdout validation / Train/test split**
#         - use sklearn `train_test_split`
#
#
# 5. **[iNTERPRET](#iNTERPRET)**
#     - **Assessing the model:**
#         - Assess parameters (slope,intercept)
#         - Check if the model explains the variation in the data (RMSE, F, R_square)
#         - *Are the coeffs, slopes, intercepts in appropriate units?*
#         - *Whats the impact of collinearity? Can we ignore?*
#         <br><br>
#     - **Revise the fitted model**
#         - Multicollinearity is big issue for lin regression and cannot fully remove it
#         - Use the predictive ability of model to test it (like R2 and RMSE)
#         - Check for missed non-linearity
#
#
# 6. **Interpret final model and draw >=3 conclusions and recommendations from dataset**

# %% [markdown]
# <div style="display:block;border-bottom:solid red 3px;padding:1.4em;color:red;font-size:30pt;display:inline-block;line-height:1.5em;">
# DELETE THIS CELL AND EVERYTHING ABOVE FROM YOUR FINAL NOTEBOOK
# </div>

# %% [markdown]
# # Final Project Submission

# %% [markdown]
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time:
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:
# * Video of 5-min Non-Technical Presentation:

# %% [markdown]
# ## TABLE OF CONTENTS

# %% [markdown]
# *Click to jump to matching Markdown Header.*<br><br>
#
# - **[Introduction](#INTRODUCTION)<br>**
# - **[OBTAIN](#OBTAIN)**<br>
# - **[SCRUB](#SCRUB)**<br>
# - **[EXPLORE](#EXPLORE)**<br>
# - **[MODEL](#MODEL)**<br>
# - **[iNTERPRET](#iNTERPRET)**<br>
# - **[Conclusions/Recommendations](#CONCLUSIONS-&-RECOMMENDATIONS)<br>**
# ___

# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# > Explain the point of your project and what question you are trying to answer with your modeling.
#
# ## Business Problem
#
# Summary of the business problem you are trying to solve, and the data questions that you plan to answer to solve them.
#
# ***
# Questions to consider:
# * What are the business's pain points related to this project?
# * How did you pick the data analysis question(s) that you did?
# * Why are these questions important from a business perspective?
# ***

# %% [markdown]
# # OBTAIN

# %% [markdown]
# ## Imports & Functions

# %%
import os
print("PYTHONPATH:", os.environ.get('PYTHONPATH'))
print("PATH:", os.environ.get('PATH'))
# Out:
# PYTHONPATH: None
# PATH: /opt/anaconda3/bin:/opt/anaconda3/envs/learn-env-graphviz/bin:/opt/anaconda3/condabin:/Applications⁩/Postgres.app⁩/⁨Contents⁩/Versions⁩/12/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/usr/local/share/npm/bin:/Users/jamesirving/.local/bin:/Users/jamesirving:/Library/TeX/texbin:/usr/local/share/dotnet:/opt/X11/bin:~/.dotnet/tools:/Applications/Postgres.app/Contents/Versions/latest/bin⁩:/opt/WebDriver/bin

# %%
## Loading a modified copy of study group functions
# %load_ext autoreload
# %autoreload 2
import functions_SG as sg

# %%
# import matplotlib.ticker as mtick
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import plotly.express as px

import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy import stats

import pandas as pd
pd.set_option('display.max_columns',0)
pd.set_option('display.float_format', lambda x: f"{x:,}")
sns.__version__
# Out:
# '0.11.0'

# %%
from scipy import stats

def find_outliers_z(data):
    """Detects outliers using the Z-score>3 cutoff.
    Returns a boolean Series where True=outlier"""
    zFP = np.abs(stats.zscore(data))
    zFP = pd.Series(zFP, index=data.index)
    idx_outliers = zFP > 3
    return idx_outliers


def find_outliers_IQR(data):
    """Detects outliers using the 1.5*IQR thresholds.
    Returns a boolean Series where True=outlier"""
    res = data.describe()
    q1 = res['25%']
    q3 = res['75%']
    thresh = 1.5*(q3-q1)
    idx_outliers =(data < (q1-thresh)) | (data > (q3+thresh))
    return idx_outliers

def color_above_thresh(val,thresh=0.05):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val > thresh else 'black'
    return 'color: %s' % color


def check_null_cols(df,above_cutoff=True,percent_cutoff=5):
    """Displays null values for columns that have nulls > 0.
    Returns index of columns """
    ## Get Nulls, filter >0
    nulls = df.isna().sum()
    nulls = nulls[nulls>0]

    ## make into a df
    null_df = pd.DataFrame({'# null':nulls,
                            '% null': (nulls/len(df)*100).round(2)})
    
    null_df.sort_values('% null',ascending=False,inplace=True)
    null_df['Droppable'] = null_df['% null'] < percent_cutoff

    s = null_df
#     display(s.style.set_caption('Null Values '))
    return s

def column_report(df):
    """Returns a dataframe with the following summary information
    for each column in df.
    - Dtype
    - # Unique Entries
    - # Null Values
    - # Non-Null Values
    - % Null Values
    """
    report = pd.DataFrame({'dtype':df.dtypes, 
          
             'nunique':df.nunique(),
               '# Nulls': df.isna().sum(),
              '# Non-Nulls':df.notnull().sum(),
                          }).reset_index().rename({'index':'column'},axis=1)
    report[''] = range(len(report))
    report.set_index('',inplace=True)
    report['% null'] = np.round(report['# Nulls']/len(df)*100,2)
    return report

# %% [markdown]
# <details>
#     <summary>
#         <h4> > Data Understanding (click)</h4>
#     </summary>
#
#
# Describe the data being used for this project.
# ***
# Questions to consider:
# * Where did the data come from, and how do they relate to the data analysis questions?
# * What do the data represent? Who is in the sample and what variables are included?
# * What is the target variable?
# * What are the properties of the variables you intend to use?
# ***
#  </details>

# %%
df = pd.read_csv('data/kc_house_data.csv',
                 parse_dates=['date'],
#                  na_values=['?']
                )
df
# Out:
#                id       date  ...  sqft_living15  sqft_lot15
# 0      7129300520 2014-10-13  ...           1340        5650
# 1      6414100192 2014-12-09  ...           1690        7639
# 2      5631500400 2015-02-25  ...           2720        8062
# 3      2487200875 2014-12-09  ...           1360        5000
# 4      1954400510 2015-02-18  ...           1800        7503
# ...           ...        ...  ...            ...         ...
# 21592   263000018 2014-05-21  ...           1530        1509
# 21593  6600060120 2015-02-23  ...           1830        7200
# 21594  1523300141 2014-06-23  ...           1020        2007
# 21595   291310100 2015-01-16  ...           1410        1287
# 21596  1523300157 2014-10-15  ...           1020        1357
#
# [21597 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  datetime64[ns]
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %% [markdown]
# # SCRUB

# %%
column_report(df)
# Out:
#            column           dtype  nunique  # Nulls  # Non-Nulls  % null
#
# 0              id           int64    21420        0        21597     0.0
# 1            date  datetime64[ns]      372        0        21597     0.0
# 2           price         float64     3622        0        21597     0.0
# 3        bedrooms           int64       12        0        21597     0.0
# 4       bathrooms         float64       29        0        21597     0.0
# 5     sqft_living           int64     1034        0        21597     0.0
# 6        sqft_lot           int64     9776        0        21597     0.0
# 7          floors         float64        6        0        21597     0.0
# 8      waterfront         float64        2     2376        19221    11.0
# 9            view         float64        5       63        21534    0.29
# 10      condition           int64        5        0        21597     0.0
# 11          grade           int64       11        0        21597     0.0
# ...

# %% [markdown]
# ## Scrubbing Observations

# %% [markdown]
# - `id`:
#     - nunique for `id` does NOT match Non-Nuls.
#         - [ ] Check for duplicate homes
#
# - `sqft_basement`:
#     - dtype=object
#         - [ ] Recast as float
#
# - `waterfront`:
#     - Many null values (11% of column)
#         - [ ] fill with column's mode
#
# - `view`:
#     - Null values (only 0.3% of column).
#         - [ ] Drop nulls
#
# - `yr_renovated`:
#     - Null values (17% of column)
#     - Assuming missing value means not reovated.
#         - [ ] Replace with binary `was_renovated` column

# %% [markdown]
# ### Removing Duplicate `id`s

# %%
## DSorting by id and date to inspect duplicate homes
df = df.sort_values(['id','date'],ascending=False)
df[df.duplicated('id',keep=False)]
# Out:
#                id       date     price  ...     long  sqft_living15  sqft_lot15
# 1085   9834200885 2015-04-20 550,000.0  ...  -122.29           1340        4080
# 1084   9834200885 2014-07-17 360,000.0  ...  -122.29           1340        4080
# 15186  9834200305 2015-02-10 615,000.0  ... -122.288           1360        4080
# 15185  9834200305 2014-07-16 350,000.0  ... -122.288           1360        4080
# 6340   9828200460 2015-01-06 430,000.0  ...   -122.3           1440        4800
# ...           ...        ...       ...  ...      ...            ...         ...
# 11421   109200390 2014-08-20 245,000.0  ... -122.367           1830        6956
# 16801     7200179 2015-04-24 175,000.0  ... -122.211           1480        6969
# 16800     7200179 2014-10-16 150,000.0  ... -122.211           1480        6969
# 2495      1000102 2015-04-22 300,000.0  ... -122.214           2060        7316
# 2494      1000102 2014-09-16 280,000.0  ... -122.214           2060        7316
#
# ...

# %%
## Keeping the most recent date
df.drop_duplicates(keep='first',subset=['id'],inplace=True)

## sort by index and drop uneeded columns
df.sort_index(inplace=True)

## Confirming duplicates removed
df[df.duplicated('id',keep=False)]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []

# %%
## Dropping cols now that confirmed duplicates removed
df.drop(columns=['id','date'],inplace=True)
df
# Out:
#           price  bedrooms  ...  sqft_living15  sqft_lot15
# 0     221,900.0         3  ...           1340        5650
# 1     538,000.0         3  ...           1690        7639
# 2     180,000.0         2  ...           2720        8062
# 3     604,000.0         4  ...           1360        5000
# 4     510,000.0         3  ...           1800        7503
# ...         ...       ...  ...            ...         ...
# 21592 360,000.0         3  ...           1530        1509
# 21593 400,000.0         4  ...           1830        7200
# 21594 402,101.0         2  ...           1020        2007
# 21595 400,000.0         3  ...           1410        1287
# 21596 325,000.0         2  ...           1020        1357
#
# [21420 rows x 19 columns]

# %% [markdown]
# ### `sqft_basement`

# %% [markdown]
# - convert to float or int
# - "?" present in data.
#     - [ ] replace with null values

# %%
df['sqft_basement'] = pd.to_numeric(df['sqft_basement'],errors='coerce')

# %%
column_report(df)
# Out:
#            column    dtype  nunique  # Nulls  # Non-Nulls  % null
#
# 0           price  float64     3595        0        21420     0.0
# 1        bedrooms    int64       12        0        21420     0.0
# 2       bathrooms  float64       29        0        21420     0.0
# 3     sqft_living    int64     1034        0        21420     0.0
# 4        sqft_lot    int64     9776        0        21420     0.0
# 5          floors  float64        6        0        21420     0.0
# 6      waterfront  float64        2     2353        19067   10.99
# 7            view  float64        5       63        21357    0.29
# 8       condition    int64        5        0        21420     0.0
# 9           grade    int64       11        0        21420     0.0
# 10     sqft_above    int64      942        0        21420     0.0
# 11  sqft_basement  float64      303      452        20968    2.11
# 12       yr_built    int64      116        0        21420     0.0
# ...

# %%
df.describe()['sqft_basement']
# Out:
# count             20,968.0
# mean    292.10086798931707
# std     442.70155806399737
# min                    0.0
# 25%                    0.0
# 50%                    0.0
# 75%                  560.0
# max                4,820.0
# Name: sqft_basement, dtype: float64

# %% [markdown]
# - Created 2% null values for sqft_basement.
#     - Since 0 is already present in data, I don't want to assume these should be zeros.
#     - [ ] Drop nulls (since <5% of data)

# %%
df.dropna(subset=['sqft_basement'],inplace=True)

# %% [markdown]
# ### `view`

# %%
column_report(df)
# Out:
#            column    dtype  nunique  # Nulls  # Non-Nulls  % null
#
# 0           price  float64     3554        0        20968     0.0
# 1        bedrooms    int64       12        0        20968     0.0
# 2       bathrooms  float64       29        0        20968     0.0
# 3     sqft_living    int64     1025        0        20968     0.0
# 4        sqft_lot    int64     9643        0        20968     0.0
# 5          floors  float64        6        0        20968     0.0
# 6      waterfront  float64        2     2316        18652   11.05
# 7            view  float64        5       61        20907    0.29
# 8       condition    int64        5        0        20968     0.0
# 9           grade    int64       11        0        20968     0.0
# 10     sqft_above    int64      935        0        20968     0.0
# 11  sqft_basement  float64      303        0        20968     0.0
# 12       yr_built    int64      116        0        20968     0.0
# ...

# %%
df['waterfront'] = df['waterfront'].fillna(0)
df['waterfront'].value_counts(dropna=False)
# Out:
# 0.0    20826
# 1.0      142
# Name: waterfront, dtype: int64

# %% [markdown]
# ### `yr_renovated`

# %%
df['yr_renovated'].fillna(0,inplace=True)
df['was_renovated'] = (df['yr_renovated'] > 0).astype(int)
df.drop(columns=['yr_renovated'])

df['was_renovated'].value_counts(dropna=False)
# Out:
# 0    20249
# 1      719
# Name: was_renovated, dtype: int64

# %% [markdown]
# ## Dropping unwanted cols

# %%
dropcols = ['lat','long']#,'view']
df.drop(columns=dropcols,inplace=True)

# %%
df['view'].value_counts(dropna=False)
df['view'] = df['view'].fillna(0)

# %% [markdown]
# # EXPLORE

# %% [markdown]
# ## Checking for Linearity with Target

# %%
def plot_hist_regplot_gs(df,column,target='price',
                     figsize=(12,5),style='seaborn-notebook',
                     line_kws={'color':'black','ls':':'},
                    scatter_kws={'s':3},cat=False):
    
    with plt.style.context(style):
        fig = plt.figure(figsize=figsize,constrained_layout=True)

        gs = fig.add_gridspec(nrows=2,ncols=3,)
        ax1 = fig.add_subplot(gs[0,2])
        ax2 = fig.add_subplot(gs[1,2])
        ax3 = fig.add_subplot(gs[:2,:2])
        

        if cat == True:
#             sns.barplot(data=df,x=column, y=target, ax=ax3,palette='dark',
#                         estimator=np.median)
            sns.stripplot(data=df,x=column,size=3, y=target,alpha=0.5, ax=ax3,palette='dark')
            hist_discrete = True
        else:
            # regplot
            hist_discrete = None
            sns.regplot(data=df,x=column, y=target, ax=ax3,
                        line_kws=line_kws, scatter_kws=scatter_kws)
        ## Histogram
        sns.histplot(data=df, x=column,stat='probability',discrete=hist_discrete,
                     ax=ax1)
                
        ## boxplot
        sns.boxplot(data=df,x=column,ax=ax2)
        
    fig.suptitle(f'Inspecting {column} vs {target}',y=1.05)
        
    return fig, (ax1,ax2,ax3)

# %%
# plot_hist_regplot_gs(df,'bedrooms',cat=True);
# plt.show()
# plot_hist_regplot_gs(df,'bedrooms');

# %%
## Save list of cols not used for modeing

num_cols = list(df.select_dtypes('number').columns)
num_cols.remove('price')
num_cols
# Out:
# ['bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'sqft_living15',
#  'sqft_lot15',
#  'was_renovated']

# %%
# ## Loop through all numeric cols and plot data
# for col in num_cols:
#     print('---'*30)
#     print(f"{col}:")
#     print("\tRaw Data:")
    
#     plot_hist_regplot_gs(df,col)
#     plt.show()
    
# #     print("\n\tOutliers Removed")
# #     col_outliers = find_outliers_IQR(df[col])
# #     plot_hist_regplot_gs(df[~col_outliers],col)
# #     plt.show() 
#     print('\n'*2)

# %%
plot_hist_regplot_gs(df,'condition',cat=True);

# %% [markdown]
# ### bedrooms

# %%
# plot_hist_regplot_gs(df,'bedrooms');

# %%
# plot_hist_regplot_gs(df,'bedrooms',cat=True);

# %%
# sns.heatmap()

# %%
plot_hist_regplot_gs(df,'sqft_lot',cat=False);

# %%
outliers = find_outliers_z(df['sqft_lot'])#np.abs(stats.zscore(df['bedrooms'])) > 3
plot_hist_regplot_gs(df[~outliers],'sqft_lot',cat=False)
# Out:
# (<Figure size 864x360 with 3 Axes>,
#  (<AxesSubplot:xlabel='sqft_lot', ylabel='Probability'>,
#   <AxesSubplot:xlabel='sqft_lot'>,
#   <AxesSubplot:xlabel='sqft_lot', ylabel='price'>))

# %% [markdown]
# <!-- ## Data Preparation
#
# Describe and justify the process for preparing the data for analysis.
#
# ***
# Questions to consider:
# * Were there variables you dropped or created?
# * How did you address missing values or outliers?
# * Why are these choices appropriate given the data and the business problem?
# *** -->

# %%
df.isna().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# sqft_living15    0
# sqft_lot15       0
# was_renovated    0
# dtype: int64

# %% [markdown]
# ## Multicollinearity

# %%
sg.multiplot(df,drop='price',cmap='Blues',use_mask=False)
# Out:
# (<Figure size 864x864 with 2 Axes>, <AxesSubplot:>)

# %%
def get_list_of_corrs(df,drop='price',
                      cutoff=0.75,only_above_cutoff=False,
                     sort_by_col=False):
    
    corr_df = df.drop(drop,axis=1).corr().unstack().reset_index()
    
    ## Remove self-correlations
    corr_df = corr_df.loc[ corr_df['level_0']!=corr_df['level_1']]
    
    ## Make one column with unique names
    corr_df['columns'] = corr_df.apply(
        lambda row: '_'.join(set(row[['level_0','level_1']] )), axis=1)
    
    corr_df.drop_duplicates(subset=['columns'],inplace=True)
    

    
    corr_df['above_cutoff'] = corr_df[0] > cutoff
    
#     corr_df = corr_df[['Column1','Column2','r-value','above_cutoff']].round(2)
    
    if sort_by_col:
        corr_df = corr_df.sort_values( ['Column1','Column2'],ascending=True)
    else:
        corr_df =  corr_df.sort_values(0,ascending=False)
        
    corr_df.rename({0:'r-value','level_0':'Column1',
               'level_1':'Column2'},axis=1,inplace=True)

    if only_above_cutoff:
        corr_df = corr_df[corr_df['above_cutoff']==True]
        
    ## Reset Index for Aesthetics
    corr_df.reset_index(drop=True)
    return corr_df.round(2)

corr_df = get_list_of_corrs(df,cutoff=0.75, only_above_cutoff=True)
corr_df
# Out:
#           Column1        Column2  ...                     columns above_cutoff
# 220  yr_renovated  was_renovated  ...  yr_renovated_was_renovated         True
# 43    sqft_living     sqft_above  ...      sqft_above_sqft_living         True
# 42    sqft_living          grade  ...           grade_sqft_living         True
# 145         grade     sqft_above  ...            sqft_above_grade         True
# 48    sqft_living  sqft_living15  ...   sqft_living_sqft_living15         True
# 19      bathrooms    sqft_living  ...       bathrooms_sqft_living         True
#
# [6 rows x 5 columns]

# %% [markdown]
# - Columns with High Correlation (>0.75):
#     - sqft_above & sqft_living
#     - sqft_living	grade
#     - sqft_living_15 & sqft_living
#     - sqft_above & grade

# %% [markdown]
# ### Explore 2: Multicollinearity with VIF
#
# Definition: when 2 features are more related to each than the target.
#
# > $\large V.I.F. = \frac{1}{(1 - R^2)} $<br>
# - [VIF (Variance Inflation Factor)](https://etav.github.io/python/vif_factor_python.html)
# - [Wikipedia: VIF](https://en.wikipedia.org/wiki/Variance_inflation_factor)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calc_vif(X_,drop=None,cutoff=5):
    """Calculates VIF scores for all columns.
    Modified from source: https://etav.github.io/python/vif_factor_python.html"""
    if drop is not None:
        X = X_.drop(columns=drop).copy()
    else:
        X = X_.copy()
    vif = pd.DataFrame()
    vif["features"] = X.columns
    vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif['above_cutoff'] = vif['VIF Factor'] > cutoff
    return vif.round(2).sort_values('VIF Factor',ascending=False)

# calc_vif(df,drop=['price'])

# %%
df.isna().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# sqft_living15    0
# sqft_lot15       0
# was_renovated    0
# dtype: int64

# %%
df
# Out:
#           price  bedrooms  bathrooms  ...  sqft_living15  sqft_lot15  was_renovated
# 0     221,900.0         3        1.0  ...           1340        5650              0
# 1     538,000.0         3       2.25  ...           1690        7639              1
# 2     180,000.0         2        1.0  ...           2720        8062              0
# 3     604,000.0         4        3.0  ...           1360        5000              0
# 4     510,000.0         3        2.0  ...           1800        7503              0
# ...         ...       ...        ...  ...            ...         ...            ...
# 21592 360,000.0         3        2.5  ...           1530        1509              0
# 21593 400,000.0         4        2.5  ...           1830        7200              0
# 21594 402,101.0         2       0.75  ...           1020        2007              0
# 21595 400,000.0         3        2.5  ...           1410        1287              0
# ...

# %%
sns.lmplot(data=df, x='sqft_living',y='price',
           col='bedrooms',col_wrap=3,hue='bedrooms',aspect=1)

# %% [markdown]
# # MODEL

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer

# %% [markdown]
# ## Prepare X and y for modeling

# %%
def make_X_y(df,y_col='price',x_cols=None,exclude=[],
            add_constant=True):
    
    if x_cols is None:
        x_cols = list(df.drop(columns=y_col).columns)
    
    [x_cols.remove(col) for col in exclude]

    X = df[x_cols].copy()
    y = df[y_col].copy()
    
    if add_constant == True:
        X = sm.add_constant(X)
        
    return X,y

X,y = make_X_y(df)

# %%
f = 'price~C(zipcode)'
smf.ols(f, df).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.404
# Method:                 Least Squares   F-statistic:                     207.3
# Date:                Fri, 16 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:00:43   Log-Likelihood:            -2.9302e+05
# No. Observations:               20968   AIC:                         5.862e+05
# Df Residuals:                   20898   BIC:                         5.867e+05
# Df Model:                          69
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
cat_cols=['zipcode']
encoder = OneHotEncoder(sparse=False,drop='first',dtype='int')

zip_data = pd.DataFrame(encoder.fit_transform(X[cat_cols]),
                        columns=encoder.get_feature_names(cat_cols),
                       index=X.index)
df_ohe = pd.concat([X.drop(columns=cat_cols),zip_data],axis=1)
df_ohe
# Out:
#        const  bedrooms  bathrooms  ...  zipcode_98188  zipcode_98198  zipcode_98199
# 0        1.0         3        1.0  ...              0              0              0
# 1        1.0         3       2.25  ...              0              0              0
# 2        1.0         2        1.0  ...              0              0              0
# 3        1.0         4        3.0  ...              0              0              0
# 4        1.0         3        2.0  ...              0              0              0
# ...      ...       ...        ...  ...            ...            ...            ...
# 21592    1.0         3        2.5  ...              0              0              0
# 21593    1.0         4        2.5  ...              0              0              0
# 21594    1.0         2       0.75  ...              0              0              0
# 21595    1.0         3        2.5  ...              0              0              0
# ...

# %%
def one_hot_encode(X, cat_cols,encoder=None):
    """Uses sklearn OneHotEncoder to encode the list of cat_cols.
    If encoder is provided, it will use .transform, otherwise it will
    fit a new one.
    
    Returns:
        df_ohe: dataframe of all data with ohe_cols
        encoder: OneHotEncoder used.
    """
    
    ## If no encoder provided, fit a new one

    if encoder is None:
        encoder = OneHotEncoder(sparse=False,drop='first',dtype='int')
        data = encoder.fit_transform(X[cat_cols])
    else:
        data = encoder.transform(X[cat_cols])
    
    ## convert the data back to a dataframe
    ohe_data = pd.DataFrame(data,
                            columns=encoder.get_feature_names(cat_cols),
                           index=X.index)
    df_ohe = pd.concat([X.drop(columns=cat_cols),ohe_data],axis=1)
    
    return df_ohe, encoder

# %%
X,y = make_X_y(df)
X_ohe,encoder = one_hot_encode(X,cat_cols=['zipcode'])

X_ohe
# Out:
#        const  bedrooms  bathrooms  ...  zipcode_98188  zipcode_98198  zipcode_98199
# 0        1.0         3        1.0  ...              0              0              0
# 1        1.0         3       2.25  ...              0              0              0
# 2        1.0         2        1.0  ...              0              0              0
# 3        1.0         4        3.0  ...              0              0              0
# 4        1.0         3        2.0  ...              0              0              0
# ...      ...       ...        ...  ...            ...            ...            ...
# 21592    1.0         3        2.5  ...              0              0              0
# 21593    1.0         4        2.5  ...              0              0              0
# 21594    1.0         2       0.75  ...              0              0              0
# 21595    1.0         3        2.5  ...              0              0              0
# ...

# %% [markdown]
# ## Model 1

# %% [markdown]
# ### Data Modeling
# Describe and justify the process for analyzing or modeling the data.
#
# ***
# Questions to consider:
# * How did you analyze or model the data?
# * How did you iterate on your initial approach to make it better?
# * Why are these choices appropriate given the data and the business problem?
# ***

# %%
def make_ols(X,y,show_summary=True,diagnose=True):
    """Fits a statsmodels OLS on X and y. 
    Optionally displays the .summary and runs diagnose_model
    
    Returns: 
        model: fit statsmodels OLS"""
    
    model = sm.OLS(y,X).fit()
    
    ## Display summary
    if show_summary:
        display(model.summary())
        
    ## Plot Q-Qplot & model residuals
    if diagnose:
        try:
            fig,ax = diagnose_model(model,x_data=X)
            plt.show()
        except Exception as e:
            print('ERROR:')
            print(e)

    return model



def diagnose_model(model,x_data = None):
    """
    Plot Q-Q plot and model residuals from statsmodels ols model.
    
    Args:
        model (smf.ols model): statsmodels formula ols 
    
    Returns:
        fig, ax: matplotlib objects
    """
    
#     
    
    fig,ax = plt.subplots(ncols=2,figsize=(10,5))

    
    if x_data is None:
        xs = np.linspace(0,1,len(resids))
        resids = model.resid
    else: 
        y_hat = model.predict(x_data,transform=True)
        resids = y-y_hat
        
    sm.qqplot(resids, stats.distributions.norm,
              fit=True, line='45',ax=ax[0])        
    ax[1].scatter(x=y_hat,y=resids,s=2)
    ax[1].set(ylabel='Residuals',xlabel='Predicted')
    ax[1].axhline(0)
    ax[1].set_title('Residuals vs Preds')
    
    plt.tight_layout()
    plt.show()
    return fig,ax

# %%
## make our baseline model
model1= make_ols(X_ohe,y)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.808
# Model:                            OLS   Adj. R-squared:                  0.807
# Method:                 Least Squares   F-statistic:                     1044.
# Date:                Fri, 16 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:00:44   Log-Likelihood:            -2.8121e+05
# No. Observations:               20968   AIC:                         5.626e+05
# Df Residuals:                   20883   BIC:                         5.633e+05
# Df Model:                          84
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
y_hat = model1.predict(X_ohe)
resids = y - y_hat

plt.scatter(y_hat,resids)
plt.axhline()

# %%
model1= make_ols(X_ohe,np.log(y))
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.878
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     1795.
# Date:                Fri, 16 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:00:45   Log-Likelihood:                 5890.1
# No. Observations:               20968   AIC:                        -1.161e+04
# Df Residuals:                   20883   BIC:                        -1.093e+04
# Df Model:                          84
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
X_ohe
# Out:
#        const  bedrooms  bathrooms  ...  zipcode_98188  zipcode_98198  zipcode_98199
# 0        1.0         3        1.0  ...              0              0              0
# 1        1.0         3       2.25  ...              0              0              0
# 2        1.0         2        1.0  ...              0              0              0
# 3        1.0         4        3.0  ...              0              0              0
# 4        1.0         3        2.0  ...              0              0              0
# ...      ...       ...        ...  ...            ...            ...            ...
# 21592    1.0         3        2.5  ...              0              0              0
# 21593    1.0         4        2.5  ...              0              0              0
# 21594    1.0         2       0.75  ...              0              0              0
# 21595    1.0         3        2.5  ...              0              0              0
# ...

# %%
model1.predict(X_ohe)
# Out:
# 0       12.379232731685065
# 1       13.157762208225105
# 2       12.616171630406148
# 3        13.18721603727003
# 4       13.050709492955258
#                ...
# 21592   13.191131415541957
# 21593   12.887654883147649
# 21594   12.753067244379418
# 21595   12.927125448776208
# 21596   12.753361736072115
# Length: 20968, dtype: float64

# %%
plt.scatter(np.arange(0,len(model1.resid)),model1.resid)
plt.axhline()

# %%
plt.scatter(model1.predict(X_ohe),model1.resid)
plt.axhline()

# %% [markdown]
# #### Model Interpretation

# %% [markdown]
# -

# %% [markdown]
# #### Remove Outliers from target

# %%
outliers_price = find_outliers_IQR(df['price'])
outliers_price
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21592    False
# 21593    False
# 21594    False
# 21595    False
# 21596    False
# Name: price, Length: 20968, dtype: bool

# %%
model = make_ols(X_ohe[~outliers_price],y[~outliers_price])
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.834
# Model:                            OLS   Adj. R-squared:                  0.834
# Method:                 Least Squares   F-statistic:                     1183.
# Date:                Fri, 16 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:00:47   Log-Likelihood:            -2.5320e+05
# No. Observations:               19838   AIC:                         5.066e+05
# Df Residuals:                   19753   BIC:                         5.072e+05
# Df Model:                          84
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
outlier_cols = list(df.select_dtypes('number').columns)
[outlier_cols.remove(col) for col in ['waterfront','zipcode'] ] 
outlier_cols
# Out:
# ['price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'sqft_living15',
#  'sqft_lot15',
#  'was_renovated']

# %%
## Getting All Outlier Indices 
outliers = {'z':{}, 'iqr':{}}

for col in outlier_cols:
    outliers['iqr'][col] = find_outliers_IQR(df[col])
    outliers['z'][col] = find_outliers_z(df[col])
    
outliers['iqr']['price'].sum()
# Out:
# 1130

# %%
outlier_df = pd.DataFrame({'IQR':pd.concat(outliers['iqr'],axis=1).any(axis=1),
                           'Z':pd.concat(outliers['z'],axis=1).any(axis=1)})
outlier_df
# Out:
#          IQR      Z
# 0      False  False
# 1       True   True
# 2      False  False
# 3      False  False
# 4      False  False
# ...      ...    ...
# 21592  False  False
# 21593  False  False
# 21594  False  False
# 21595  False  False
# 21596  False  False
#
# [20968 rows x 2 columns]

# %%
all_outliers = outlier_df['IQR']
X_clean = X_ohe[~all_outliers]
y_clean = y[~all_outliers]

model = make_ols(X_clean,y_clean)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.831
# Model:                            OLS   Adj. R-squared:                  0.830
# Method:                 Least Squares   F-statistic:                     897.6
# Date:                Fri, 16 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:00:47   Log-Likelihood:            -1.8589e+05
# No. Observations:               14716   AIC:                         3.719e+05
# Df Residuals:                   14635   BIC:                         3.726e+05
# Df Model:                          80
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# # iNTERPRET

# %% [markdown]
# Evaluate how well your work solves the stated business problem.
#
# ***
# Questions to consider:
# * How do you interpret the results?
# * How well does your model fit your data? How much better is this than your baseline model?
# * How confident are you that your results would generalize beyond the data you have?
# * How confident are you that this model would benefit the business if put into use?
# ***

# %% [markdown]
# # CONCLUSIONS & RECOMMENDATIONS

# %% [markdown]
# Provide your conclusions about the work you've done, including any limitations or next steps.
#
# ***
# Questions to consider:
# * What would you recommend the business do as a result of this work?
# * What are some reasons why your analysis might not fully solve the business problem?
# * What else could you do in the future to improve this project?
# ***

# %% [markdown]
# # APPENDIX/REMOVED

# %%
def make_ols_f(df,target='price',col_list=None,exclude_cols=[],
               cat_cols = [],  show_summary=True,
               diagnose=True, fit_intercept=True):
    """
    Makes statsmodels formula-based regression with options to make categorical columns.    
    Args:
        df (Frame): df with data
        target (str): target column name
        col_list (list, optional): List of predictor columns. Defaults to all except target.
        exclude_cols (list, optional): Columns to remove from col_list. Defaults to [].
        cat_cols (list, optional): Columns to process as categorical using f'C({col})". Defaults to [].
        show_summary (bool, optional): Display model.summary(). Defaults to True.
        diagnose (bool, optional): Plot Q-Q plot & residuals. Defaults to True.
        return_formula (bool, optional): Return formula with model. Defaults to False.
    
    Returns:
        model : statsmodels ols model
        formula : str formula from model, only if return_formula == True
        
    
    """
    if col_list is None:
        col_list = list(df.drop(target,axis=1).columns)
        
    ## remove exclude cols
    [col_list.remove(ecol) for ecol in exclude_cols if ecol in col_list]

    ## Make rightn side of formula eqn
    features = '+'.join(col_list)

    # ADD C() around categorical cols
    for col in cat_cols:
        features = features.replace(col,f"C({col})")

    ## MAKE FULL FORMULA
#     print
    formula = target+'~'+features #target~predictors
    print(formula)
    
    if fit_intercept==False:
        formula += "-1"
    ## Fit model
    model = smf.ols(formula=formula, data=df).fit()
    
    ## Display summary
    if show_summary:
        display(model.summary())
        
    ## Plot Q-Qplot & model residuals
    if diagnose:
        try:
            fig,ax = diagnose_model(model,x_data=df)
            plt.show()
        except Exception as e:
            print('ERROR:')
            print(e)
    # Returns formula or just mmodel
        return model

# %%
sns.catplot(data=df,x='condition',y='price')

# %%
sns.catplot(data=df,x='grade',y='price')

# %%
modelf = make_ols_f(df,cat_cols=['zipcode'])
# y_hat = model1.predict(pd.concat)
# y_hat
# Out:
# price~bedrooms+bathrooms+sqft_living+sqft_lot+floors+waterfront+view+condition+grade+sqft_above+sqft_basement+yr_built+yr_renovated+C(zipcode)+sqft_living15+sqft_lot15+was_renovated
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.808
# Model:                            OLS   Adj. R-squared:                  0.807
# Method:                 Least Squares   F-statistic:                     1044.
# Date:                Fri, 16 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:00:49   Log-Likelihood:            -2.8121e+05
# No. Observations:               20968   AIC:                         5.626e+05
# Df Residuals:                   20883   BIC:                         5.633e+05
# Df Model:                          84
# Covariance Type:            nonrobust
# ...

# %%
coeff_df = pd.DataFrame({'coeffs':modelf.params,'abs_coeffs':modelf.params.abs()})
coeff_df.sort_values('abs_coeffs').tail(20)['coeffs'].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
modelf.params.round(2).sort_values()
# Out:
# was_renovated         -5,803,678.36
# floors                   -44,481.43
# C(zipcode)[T.98092]      -39,798.27
# C(zipcode)[T.98023]      -35,221.79
# bedrooms                 -27,360.85
#                            ...
# C(zipcode)[T.98112]      620,287.63
# waterfront               696,954.03
# C(zipcode)[T.98004]      772,124.15
# Intercept                956,650.07
# C(zipcode)[T.98039]    1,308,134.41
# Length: 86, dtype: float64

# %%
sns.catplot(data=df, x='bedrooms',y='price')

# %%
modelf = make_ols_f(df,cat_cols=['zipcode','bedrooms'],fit_intercept=False)
# Out:
# price~C(bedrooms)+bathrooms+sqft_living+sqft_lot+floors+waterfront+view+condition+grade+sqft_above+sqft_basement+yr_built+yr_renovated+C(zipcode)+sqft_living15+sqft_lot15+was_renovated
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.808
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     937.1
# Date:                Fri, 16 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:00:52   Log-Likelihood:            -2.8116e+05
# No. Observations:               20968   AIC:                         5.625e+05
# Df Residuals:                   20873   BIC:                         5.633e+05
# Df Model:                          94
# Covariance Type:            nonrobust
# ...

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'sqft_living15',
#        'sqft_lot15', 'was_renovated'],
#       dtype='object')

# %%
target='price'
## Make rightn side of formula eqn
# features = '+'.join(col_list)
features = "sqft_living*C(bedrooms)"
# ADD C() around categorical cols
# for col in cat_cols:
#     features = features.replace(col,f"C({col})")
## MAKE FULL FORMULA
formula = target+'~'+features #target~predictors
#print(formula)
## Fit model
model = smf.ols(formula=formula,data=df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.528
# Model:                            OLS   Adj. R-squared:                  0.527
# Method:                 Least Squares   F-statistic:                     1114.
# Date:                Fri, 16 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:00:53   Log-Likelihood:            -2.9063e+05
# No. Observations:               20968   AIC:                         5.813e+05
# Df Residuals:                   20946   BIC:                         5.815e+05
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## DecisionTreeRegressor

# %%
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor,plot_tree
from sklearn.ensemble import RandomForestRegressor

# %%
X,y = make_X_y(df)
X.drop(columns=[
    'const','yr_renovated',
#     'zipcode'
],inplace=True)
X
# Out:
#        bedrooms  bathrooms  ...  sqft_lot15  was_renovated
# 0             3        1.0  ...        5650              0
# 1             3       2.25  ...        7639              1
# 2             2        1.0  ...        8062              0
# 3             4        3.0  ...        5000              0
# 4             3        2.0  ...        7503              0
# ...         ...        ...  ...         ...            ...
# 21592         3        2.5  ...        1509              0
# 21593         4        2.5  ...        7200              0
# 21594         2       0.75  ...        2007              0
# 21595         3        2.5  ...        1287              0
# 21596         2       0.75  ...        1357              0
#
# [20968 rows x 16 columns]

# %%
X_ohe,encoder = one_hot_encode(X,cat_cols=['zipcode'])
X_train,X_test, y_train, y_test = train_test_split(X_ohe,y,
                                                   test_size=0.2)
X_train.shape, X_test.shape
# Out:
# ((16774, 84), (4194, 84))

# %%
reg =RandomForestRegressor()# DecisionTreeRegressor(#max_depth=10,
#                             min_samples_leaf=10,
#                             min_samples_split=10
#                            )
reg.fit(X_train,y_train)

y_hat_test = reg.predict(X_test)
# metrics.r2_score(y_test,y_hat_test)
print(f"Training Score:\t{reg.score(X_train,y_train):.6f}")
print(f"Test Score:\t{reg.score(X_test,y_test):6f}")


## Feature Importances
pd.Series(reg.feature_importances_,
          index=X_train.columns).sort_values().tail(20).plot(kind='barh')
# Out:
# Training Score:	0.976094
# Test Score:	0.813828
# <AxesSubplot:>

# %%
def plot_reg_residuals(reg,X_train,X_test,y_train,y_test):
    """Compares the residuals for the training data and test data"""

    ## Training Predictions and R2 calculation
    y_hat_train = reg.predict(X_train)
    r2_train = metrics.r2_score(y_train,y_hat_train)
    resids_train = y_train - y_hat_train
    
    
    ## Test Data Preds, Scores, and Resids to Plot
    y_hat_test = reg.predict(X_test)
    r2_test = metrics.r2_score(y_test,y_hat_test)
    resids_test = y_test - y_hat_test


    ## Residual Plot for Trianing Vs Test Data
    fig,axes = plt.subplots(ncols=2,figsize=(12,5))

    axes[0].scatter(y_hat_train,resids_train,alpha=0.8,s=3)
    axes[0].set(title=f'Training Score = {r2_train:.5f}',
                ylabel='Residuals',xlabel='y_hat_train')

    axes[1].scatter(y_hat_test,resids_test,alpha=0.5,s=3)
    axes[1].set(title=f'Test Score = {r2_test:.5f}',
                ylabel='Residuals',xlabel='y_hat_test')

    [ax.axhline(0,color='k',zorder=-1,ls=':',lw=1) for ax in axes];
    fig.tight_layout()

plot_reg_residuals(reg,X_train,X_test,y_train,y_test)

# %%
# fig, ax = plt.subplots(figsize=(40,10))
# plot_tree(reg,feature_names=X_train.columns,
#           filled=True, rounded=True,
# #                  fontsize=12,
#           ax=ax)#,max_depth=4)
# fig.savefig('tree.png')

# %%
reg.tree_.max_depth
# Out:
# 10

# %% [markdown]
# ## Updated Visualizing Tree Method
# - https://mljar.com/blog/visualize-decision-tree/

# %%
import graphviz
from sklearn.tree import export_graphviz
dot_data = export_graphviz(reg, out_file=None, rounded=True,
                                feature_names=X_train.columns,
                                filled=True,impurity=False,
                           rotate=False)
# Draw graph
graph = graphviz.Source(dot_data,format="pdf") 
graph.render('tee_regr',cleanup=True,view=True)
# Out:
# 'tee_regr.pdf'

# %%
# # Draw graph
# graph = graphviz.Source(dot_data, format="pdf") 
# graph.render('tree_max_depth_20_image')

# %% [markdown]
# ## Regularization - Lasso Regression

# %%
from sklearn.linear_model import RidgeCV,LassoCV
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_sca = pd.DataFrame(scaler.fit_transform(X_train),
                           columns=X_train.columns)
X_test_sca = pd.DataFrame(scaler.transform(X_test),
                           columns=X_test.columns)

# %%
reg_cv = LassoCV(verbose=True,cv=10)
reg_cv.fit(X_train_sca,y_train)
print(reg_cv.score(X_train_sca,y_train))
print(reg_cv.score(X_test_sca,y_test))
reg_cv.coef_
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ...

# %%
coeffs = pd.Series(reg_cv.coef_,index=X_train.columns)
coeffs.sort_values()
# Out:
# yr_built         -24,510.07854366768
# bedrooms        -22,944.208516363582
# floors           -21,262.90076129543
# zipcode_98023   -14,919.255994196847
# zipcode_98092   -13,271.353551517677
#                         ...
# zipcode_98112     60,730.45506114821
# sqft_above         60,828.7473097702
# grade             72,014.51543829557
# zipcode_98004     84,577.58033230848
# sqft_living      116,002.36308486262
# Length: 84, dtype: float64

# %%
coeffs[coeffs==0.0]
# Out:
# sqft_basement   0.0
# dtype: float64

# %% [markdown]
# ## SGD Regressor

# %%
X_train
# Out:
#        bedrooms  bathrooms  ...  zipcode_98198  zipcode_98199
# 20295         3       1.75  ...              0              0
# 12507         3        1.5  ...              0              0
# 20075         4        2.5  ...              0              0
# 13467         2        1.0  ...              0              0
# 6943          3        2.0  ...              0              0
# ...         ...        ...  ...            ...            ...
# 5484          4        2.5  ...              0              0
# 20159         4        2.5  ...              0              0
# 8661          3       1.75  ...              0              0
# 20427         3        1.5  ...              0              0
# 4961          4        2.5  ...              0              0
#
# [16774 rows x 84 columns]

# %%
from sklearn.linear_model import SGDRegressor
sgd = SGDRegressor(penalty='l1')#,learning_rate='optimal')
sgd.fit(X_train_sca,y_train)
print(sgd.score(X_train_sca,y_train))
print(sgd.score(X_test_sca,y_test))
# coeffs = pd.Series(sgd.coef_,index=X_train.columns)
# ceoffs
coeffs = pd.Series(sgd.coef_,index=X_train.columns)
coeffs.sort_values()
# Out:
# 0.8050448805815749
# 0.7885456851548762
# floors          -25,359.375036298447
# bedrooms        -24,718.350166762884
# yr_built         -20,256.63672054051
# zipcode_98092    -5,229.090882004594
# zipcode_98023    -5,165.473163761888
#                         ...
# zipcode_98112     66,785.59431785134
# grade             71,849.07147204452
# sqft_living       81,938.40458771426
# sqft_above        86,444.19006785225
# zipcode_98004     99,887.83287858403
# Length: 84, dtype: float64

# %%
# (coeffs==0.0).sum()

# %% [markdown]
# ### Old Visualizing Tree Method

# %% [markdown]
# ### Plot the decision tree

# %% [markdown]
# You can see what rules the tree learned by plotting this decision tree. To do this, you need to use additional packages such as `pytdotplus`.
#
# > **Note:** If you are run into errors while generating the plot, you probably need to install `python-graphviz` in your machine using `conda install python-graphviz`.

# %% [markdown]
# > NOTE ON INSTALLING GRAPHVIZ:
# - On windows you must [download the Graphviz installer](https://www.graphviz.org/download/)(Choose the "stable" release), install it, and then add the `bin` folder inside of it to your system's Path.
# - [To Edit your path on MaC](https://www.architectryan.com/2012/10/02/add-to-the-path-on-mac-os-x-mountain-lion/)
#
# - [TO Edit Your Path on Windows (10)](https://www.architectryan.com/2018/03/17/add-to-the-path-on-windows-10/)

# %%
# raise Exception('you must switch to learn-env-graphviz before running the following code')

# %%
# %conda install python-graphviz

# %%
# from sklearn.tree import DecisionTreeClassifier 
from sklearn.tree import export_graphviz,plot_tree
from IPython.display import Image  
from pydotplus import graph_from_dot_data

# %%
# from pydotplus import find_graphviz
# find_graphviz()

# %%
# # Create DOT data
# dot_data = export_graphviz(reg, out_file='tree.dot', 
#                            feature_names=X_train.columns,  
# #                            class_names=['No Game','Play Game'],#np.unique(y).astype('str'), 
#                            filled=True, rounded=True,proportion=True,
#                            special_characters=True)
# !dot -Tpng tree.dot -o tree.png
# # Draw graph
# # graph = graph_from_dot_data(dot_data)  

# # Show graph
# # Image(graph.create_png())

# %%
# def viz_tree(clf,X_train_ohe,y):
#     # Create DOT data
#     dot_data = export_graphviz(clf, out_file=None, 
#                                feature_names=X_train_ohe.columns,  
#                                class_names=np.unique(y).astype('str'), 
#                                filled=True, rounded=True,#proportion=True,
#                                special_characters=True)

#     # Draw graph
#     graph = graph_from_dot_data(dot_data)  

#     # Show graph
#     return Image(graph.create_png())

# %%
# viz_tree(clf,X_train_ohe,y)

# %%
# ## Built in Implementation
# from sklearn.tree import plot_tree

# plot_tree(clf,feature_names=X_train_ohe.columns,filled=True,
#           impurity=False,proportion=True,);

# %% [markdown]
# ## EDA

# %%
# sg.multiplot()

# %%
# df['bedrooms_sqft_living'] = df['bedrooms'] * df['sqft_living']
# sns.histplot(df['bedrooms_sqft_living'])

# %%
# sns.histplot(df['sqft_living'])

# %%
# pvals = modelf.pvalues
# pvals[pvals>.05]

# %%
# def plot_hist_regplot(df,column,target='price',
#                      figsize=(6,8),style='ggplot',
#                      line_kws={'color':'black','ls':':'},
#                     scatter_kws={'s':3},cat = True):
    
#     with plt.style.context(style):
#         fig, axes = plt.subplots(figsize=figsize,
#                                  nrows=3,sharex=True,gridspec_kw={
#                                      'height_ratios':[0.25,0.5,0.25]
#                                  })#,ncols=2)        
#         ## Histogram
#         sns.histplot(data=df, x=column, ax=axes[0])
        

#         if cat == True:
#             sns.pointplot(data=df,x=column, y=target, ax=axes[1],)
#         else:
#             # regplot
#             sns.regplot(data=df,x=column, y=target, ax=axes[1],
#                         line_kws=line_kws, scatter_kws=scatter_kws)
#         axes[1].set_xlabel('')
        
#         ## boxplot
#         sns.boxplot(data=df,x=column,ax=axes[2])
#         axes[0].set_title(f'Inspecting {column} vs {target}',y=1)
# #     fig.tight_layout()
        
#     return fig, axes

# %%
# import warnings
# warnings.filterwarnings('ignore')
# def plot_hist_regplot(df,column,target='price',style='seaborn-poster',
#                     figsize=(10,5),fig_filepath=None,xrot=45):
#     """
#     Plots 2 subplots: a seaborn distplot of each column, and a regplot of each column vs target.
    
#     Args:
#         df (df): Dataframe of data
#         target (str, optional): Name of target column. Defaults to 'price'.
#         style (str, optional): Matplotlib style to use. Defaults to 'seaborn-talk'.
#         stats (bool, optional): Show normality test. Defaults to False.
#         figsize (tuple, optional): Figure size Defaults to (8,3).
#         fig_filepath ([type], optional): To save, give filename to saveas. Defaults to None.
#         hist_kwds (dict, optional): Plotting **kwargs for seaborn hist. Defaults to {}.
#         scatter_kwds (dict, optional): Plotting **kwargs for seaborn scatter. Defaults to {}.
#     """
#     ## ----------- DEFINE AESTHETIC CUSTOMIZATIONS ----------- ##
#     # Axis Label fonts
#     fontTitle = {'fontsize': 16,
#             'fontweight': 'bold',
#                 'fontfamily':'serif'}
#     fontSuptitle = {**fontTitle,'fontsize':20}

#     fontAxis = {'fontsize': 14,
#             'fontweight': 'bold',
#                 'fontfamily':'serif'}

#     fontTicks = {'fontsize': 12,
#             'fontweight':'bold',
#                 'fontfamily':'serif'}

#     # Formatting dollar sign labels
#     fmtPrice = '${x:,.0f}'
#     tickPrice = mpl.ticker.StrMethodFormatter(fmtPrice)
    
#     ## Use styly context
#     with plt.style.context(style):


#         # Create figure with subplots for current column
#         # Note: in order to use identical syntax for large # of subplots (ax[i,j]), 
#         #  declare an extra row of subplots to be removed later
#         fig, axes = plt.subplots(figsize=figsize, ncols=2,facecolor='white')

        
#         ## ----- SUBPLOT 1 -----##   
#         ax = axes[0]
        
#         # Plot distplot on ax[i,j] using hist_kws and kde_kws
#         sns.histplot(data=df, x=column, color='blue',
#                     label=column+' histogram', ax=ax)
        
#         ## Set titles and labels
#         ax.set_title(column.capitalize(),fontdict=fontTitle)

#         # Set xlabels, x-ticks labels, and style
#         ax.set_xlabel(column.title(),fontdict=fontAxis)
#         ax.set_xticklabels( ax.get_xticklabels(which = 'both'),
#                            fontdict=fontTicks,
#                            rotation=xrot)
#         ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())


#         # Set ylabels, y-ticks labels, and style
#         ax.set_ylabel('Density',fontdict=fontAxis)
#         ax.set_yticklabels(ax.get_yticklabels(which='both'),fontdict=fontTicks)
#         ax.yaxis.set_major_formatter(mpl.ticker.ScalarFormatter())

#         # Set y-grid
#         ax.set_axisbelow(True)
#         ax.grid(ls='--',color='gray')


#         ## ----- SUBPLOT 2-----  ##
#         ax = axes[1]

# #         # Define the ketword dictionaries for  scatter plot and regression line (subplot 2)
#         line_kws={"alpha":0.5,"lw":4,"ls":":"}
#         scatter_kws={'s': 2, 'alpha': 0.5,'marker':'.','color':'blue'}

#         # Plot regplot on ax[i,j] using line_kws and scatter_kws
#         sns.regplot(data=df,x=column, y=target,line_kws=line_kws,
#                     scatter_kws=scatter_kws, ax=ax)

#         ax.set_title(column.capitalize(),fontdict=fontTitle)

#         # Set xlabels, x-ticks labels, and style
#         ax.set_xlabel(column.title(),fontdict=fontAxis)
#         ax.set_xticklabels(ax.get_xticklabels(),fontdict=fontTicks, 
#                            rotation=xrot)
#         ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())

#         # Set ylabels, y-ticks labels, and style
#         ax.set_ylabel(target.title(),fontdict=fontAxis)
#         ax.set_yticklabels(ax.get_yticklabels(),fontdict=fontTicks)
#         ax.get_yaxis().set_major_formatter(tickPrice) 

#         # Set y-grid
#         ax.set_axisbelow(True)
#         ax.grid(ls='--')       


#         # Optimizing spatial layout
#         fig.suptitle(f"{column.title()} vs. {target.title()}",**fontSuptitle)
#         fig.tight_layout()

#         return fig,ax
